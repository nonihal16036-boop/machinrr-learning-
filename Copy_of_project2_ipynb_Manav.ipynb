# %% [markdown]
# <a href="https://colab.research.google.com/github/khanrimsha5009-dev/MACHINE-LEARING/blob/main/Copy_of_project2_ipynb_WARISHA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
hp = pd.read_csv(r"C:\Users\WARIS\Downloads\data (1).csv")
hp.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
hp.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
hp.shape
# Out:
# (4600, 18)

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
hp = hp.drop("date",axis=1)

# %%
hp.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip country
# ...

# %%
print(hp.columns)
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country'],
#       dtype='object')

# %%
hp.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
hp_numeric = hp.select_dtypes(include=['int64','float64'])
hp_numeric.median()
# Out:
# price            460943.461539
# bedrooms              3.000000
# bathrooms             2.250000
# sqft_living        1980.000000
# sqft_lot           7683.000000
# floors                1.500000
# waterfront            0.000000
# view                  0.000000
# condition             3.000000
# sqft_above         1590.000000
# sqft_basement         0.000000
# yr_built           1976.000000
# yr_renovated          0.000000
# dtype: float64

# %%
median_price = hp[hp['price'] > 0]['price'].median()

hp['price'] = hp['price'].replace(0.0, median_price)

print(f"The median price used was: ${median_price}")
print("Number of 0s left in price:", (hp['price'] == 0).sum())
# Out:
# The median price used was: $465000.0
# Number of 0s left in price: 0

# %%
hp.isnull().sum()
# Out:
# price                       0
# bedrooms                    0
# bathrooms                   0
# sqft_living                 0
# sqft_lot                    0
# floors                      0
# waterfront                  0
# view                        0
# condition                   0
# sqft_above                  0
# sqft_basement               0
# yr_built                    0
# yr_renovated                0
# street                      0
# statezip                    0
# country                     0
# city_Auburn                 0
# city_Beaux Arts Village     0
# city_Bellevue               0
# city_Black Diamond          0
# city_Bothell                0
# city_Burien                 0
# city_Carnation              0
# city_Clyde Hill             0
# city_Covington              0
# city_Des Moines             0
# city_Duvall                 0
# city_Enumclaw               0
# city_Fall City              0
# city_Federal Way            0
# city_Inglewood-Finn Hill    0
# ...

# %%
hp = pd.get_dummies(hp, columns=['city'], drop_first=True)

# %%
hp['yr_built'] = hp['yr_built'].astype(int)
hp['yr_renovated'] = hp['yr_renovated'].astype(int)
hp['house_age'] = 2014 - hp['yr_built']
hp.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  ...  city_Seattle  city_Shoreline  \
# 0     0          3        1340  ...         False            True
# 1     4          5        3370  ...          True           False
# 2     0          4        1930  ...         False           False
# 3     0          4        1000  ...         False           False
# 4     0          4        1140  ...         False           False
#
#    city_Skykomish city_Snoqualmie city_Snoqualmie Pass city_Tukwila  \
# ...

# %%
sns.boxplot(x=hp['price'])
plt.show()

# %%
cols = ['price','sqft_living','bedrooms']

for col in cols:
    Q1 = hp[col].quantile(0.25)
    Q3 = hp[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR

    hp = hp[(hp[col] >= lower) & (hp[col] <= upper)]

# %%
# 7 Split Features (X) and Target (y)
hp_numeric = hp.select_dtypes(include=['int64','float64'])
X = hp_numeric.drop('price', axis=1)
y = hp_numeric['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[idx]))
# Out:
# The coefficient for bedrooms is -33747.62869403906
# The coefficient for bathrooms is 47713.96495031719
# The coefficient for sqft_living is 112.15650378814897
# The coefficient for sqft_lot is -0.26853263495182944
# The coefficient for floors is 55046.53197807854
# The coefficient for waterfront is -23848.512019154878
# The coefficient for view is 25071.544603831124
# The coefficient for condition is 15402.813784245482
# The coefficient for sqft_above is 67.79314964324841
# The coefficient for sqft_basement is 44.36335399780227
# The coefficient for yr_built is -979.7210377861511
# The coefficient for yr_renovated is -0.9412883848392357
# The coefficient for house_age is 979.7210377863048

# %%
intercept = regression_model.intercept_
print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 1895909.636402253

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.45176518638568086

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.4629020839968878
